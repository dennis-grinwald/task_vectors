# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # SVHN - Resic

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
colors = ['red', 'green', 'blue', 'orange', 'purple', 'pink', 'brown', 'gray', 'cyan']
for i, j in enumerate([0,1,2,16]):
    test_acc_dict = np.load(
        f'/Users/dg/Projects/task_vectors/accs_simplex_in_layer_{j}.npy',
        allow_pickle=True
    ).item()
    cleaned_keys = [float(key) for key in test_acc_dict.keys()]
    ax[0].plot(
        cleaned_keys,
        np.array(list(test_acc_dict.values()))[:,0], linestyle='--', color=colors[i], label=f'Layer{j}'
    )
    ax[1].plot(
        cleaned_keys,
        np.array(list(test_acc_dict.values()))[:,1], linestyle='-.', color=colors[i], label=f'Layer{j}'
    )
ax[0].set_title('Task 1')
ax[1].set_title('Task 2')
ax[0].legend(
    loc='lower right'
)
ax[1].legend(
    loc='lower left'
)

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
colors = ['red', 'green', 'blue', 'orange', 'purple', 'pink', 'brown', 'gray', 'cyan']
for i, j in enumerate([20,21,22,23]):
    test_acc_dict = np.load(
        f'/Users/dg/Projects/task_vectors/accs_simplex_in_layer_{j}.npy',
        allow_pickle=True
    ).item()
    cleaned_keys = [float(key) for key in test_acc_dict.keys()]
    ax[0].plot(
        cleaned_keys,
        np.array(list(test_acc_dict.values()))[:,0], linestyle='--', color=colors[i], label=f'Layer{j}'
    )
    ax[1].plot(
        cleaned_keys,
        np.array(list(test_acc_dict.values()))[:,1], linestyle='-.', color=colors[i], label=f'Layer{j}'
    )
ax[0].set_title('Task 1')
ax[1].set_title('Task 2')
ax[0].legend(
    loc='lower right'
)
ax[1].legend(
    loc='lower left'
)
