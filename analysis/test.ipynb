# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dict_model_one_perspective = {
  0.0: (0.7885, 0.9737, (0.7885+0.9737)/2),
  0.1: (0.9199, 0.9751, (0.9199+0.9751)/2),
  0.2: (0.9767, 0.9754, (0.9767+0.9754)/2),
  0.3: (0.9921, 0.9730, (0.9921+0.9730)/2),
  0.4: (0.9950, 0.9695, (0.9950+0.9695)/2),
  0.5: (0.9968, 0.9613, (0.9968+0.9613)/2),
  0.6: (0.9972, 0.9398, (0.9972+0.9398)/2),
  0.7: (0.9973, 0.9021, (0.9973+0.9021)/2),
  0.8: (0.9974, 0.8389, (0.9974+0.8389)/2),
  0.9: (0.9971, 0.7524, (0.9971+0.7524)/2)
}

# %%
plt.plot(
    dict_model_one_perspective.keys(),
    np.array(list(dict_model_one_perspective.values()))[:,0], color='darkblue', label='Accuracy on Task 1'
)

plt.hlines(
    max(np.array(list(dict_model_one_perspective.values()))[:,0]), 0,1.0, color='darkblue'
)

plt.plot(
    dict_model_one_perspective.keys(),
    np.array(list(dict_model_one_perspective.values()))[:,1], color='orange', label='Accuracy on Task 2'
)

plt.hlines(
    max(np.array(list(dict_model_two_perspective.values()))[:,0]), 0,1.0, color='orange'
)

plt.plot(
    dict_model_one_perspective.keys(),
    np.array(list(dict_model_one_perspective.values()))[:,2], label='Multitask accuracy'
)
plt.xlabel('Model 1 weight')
plt.title('This should show that for task 1 optimal performance another weighting would be needed')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 16
#       6 plt.hlines(
#       7     max(np.array(list(dict_model_one_perspective.values()))[:,0]), 0,1.0, color='darkblue'
#       8 )
#      10 plt.plot(
#      11     dict_model_one_perspective.keys(),
#      12     np.array(list(dict_model_one_perspective.values()))[:,1], color='orange', label='Accuracy on Task 2'
#      13 )
#      15 plt.hlines(
# ---> 16     max(np.array(list(dict_model_two_perspective.values()))[:,0]), 0,1.0, color='orange'
#      17 )
#      19 plt.plot(
#      20     dict_model_one_perspective.keys(),
#      21     np.array(list(dict_model_one_perspective.values()))[:,2], label='Multitask accuracy'
#      22 )
#      23 plt.xlabel('Model 1 weight')
#
# NameError: name 'dict_model_two_perspective' is not defined
