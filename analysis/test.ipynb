# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dict_model_one_perspective = {
  0.0: (0.5269, 0.9737, 0.7503),
  0.1: (0.6863, 0.9746, 0.8305),
  0.2: (0.8129, 0.9737, 0.8933),
  0.3: (0.9035, 0.9725, 0.9380),
  0.4: (0.9503, 0.9683, 0.9593),
  0.5: (0.9705, 0.9587, 0.9646),
  0.6: (0.9784, 0.9371, 0.9578),
  0.7: (0.9805, 0.8968, 0.9387),
  0.8: (0.9812, 0.8340, 0.9076),
  0.9: (0.9816, 0.7438, 0.8627),
  1.0: (0.9811, 0.6440, 0.8126)
}

# %%
dict_model_two_perspective = {
  1.0: (0.5269, 0.9737, 0.7503),
  0.9: (0.6863, 0.9746, 0.8305),
  0.8: (0.8129, 0.9737, 0.8933),
  0.7: (0.9035, 0.9725, 0.9380),
  0.6: (0.9503, 0.9683, 0.9593),
  0.5: (0.9705, 0.9587, 0.9646),
  0.4: (0.9784, 0.9371, 0.9578),
  0.3: (0.9805, 0.8968, 0.9387),
  0.2: (0.9812, 0.8340, 0.9076),
  0.1: (0.9816, 0.7438, 0.8627),
  0.0: (0.9811, 0.6440, 0.8126)
}

# %%
plt.plot(
    dict_model_one_perspective.keys(),
    np.array(list(dict_model_one_perspective.values()))[:,0], color='darkblue', label='Accuracy on Task 1'
)
plt.plot(
    dict_model_one_perspective.keys(),
    np.array(list(dict_model_one_perspective.values()))[:,1], color='orange', label='Accuracy on Task 2'
)
plt.plot(
    dict_model_one_perspective.keys(),
    np.array(list(dict_model_one_perspective.values()))[:,2], label='Multitask accuracy'
)
plt.hlines(
    max(np.array(list(dict_model_one_perspective.values()))[:,0]), 0,1.0, color='darkblue', linestyle='--', label='Max. task 1'
)
plt.hlines(
    max(np.array(list(dict_model_one_perspective.values()))[:,1]), 0,1.0, color='orange', linestyle='--', label='Max. task 2'
)
plt.ylim(
    0.96,0.99
)
plt.xlabel(
    'Model 1 weight'
)
plt.title(
    'Task 1, 2 and Multitask accuracy'
)
plt.legend(
    loc='lower right'
)
